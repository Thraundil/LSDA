# %%
import os
import json
import pandas as pd

from tqdm import tqdm

os.chdir('D:\\02. LSDA\\github\\src')
dataset = '../data/labels/train.json'

with open(dataset, 'r') as f:
    data = json.load(f)
images = pd.DataFrame(data['images'])
annotations = pd.DataFrame(data['annotations'])
del data

# %%
sizes = []
for img_name in os.listdir('../data/images/train'):
  plt.imread('../data/images/train'img_name)
# Out:
# ['632.jpg',
#  '637.jpg',
#  '638.jpg',
#  '641.jpg',
#  '642.jpg',
#  '635.jpg',
#  '643.jpg',
#  '644.jpg',
#  '645.jpg',
#  '648.jpg',
#  '651.jpg',
#  '646.jpg',
#  '647.jpg',
#  '649.jpg',
#  '650.jpg',
#  '653.jpg',
#  '652.jpg',
#  '656.jpg',
#  '655.jpg',
#  '659.jpg',
#  '658.jpg',
#  '661.jpg',
#  '654.jpg',
#  '662.jpg',
#  '660.jpg',
#  '664.jpg',
#  '665.jpg',
#  '657.jpg',
#  '663.jpg',
#  '669.jpg',
#  '667.jpg',
#  '668.jpg',
#  '666.jpg',
#  '671.jpg',
#  '672.jpg',
#  '670.jpg',
#  '673.jpg',
#  '675.jpg',
#  '674.jpg',
#  '677.jpg',
#  '676.jpg',
#  '680.jpg',
#  '678.jpg',
#  '681.jpg',
#  '679.jpg',
#  '684.jpg',
#  '683.jpg',
#  '682.jpg',
#  '690.jpg',
#  '691.jpg',
#  '688.jpg',
#  '687.jpg',
#  '686.jpg',
#  '695.jpg',
#  '685.jpg',
#  '689.jpg',
#  '693.jpg',
#  '694.jpg',
#  '696.jpg',
#  '697.jpg',
#  '699.jpg',
#  '698.jpg',
#  '702.jpg',
#  '703.jpg',
#  '700.jpg',
#  '692.jpg',
#  '707.jpg',
#  '704.jpg',
#  '701.jpg',
#  '709.jpg',
#  '708.jpg',
# ...

# %%
#For each annotation get the frequency... Then get the first 100 keywords for that image..
anno_tuples = []
for name,row in tqdm(annotations.set_index('imageId').iterrows(),total = len(annotations)):
  for label in row['labelId']:
    anno_tuples += [(name,label)]
annotations = pd.DataFrame(anno_tuples)
annotations.columns = ['imageId','labelId']

first_100_annos = pd.DataFrame(columns = annotations.columns)
for name, group in annotations.groupby('labelId'):
  first_100_annos = first_100_annos.append(group.iloc[:100])
# Out:
# 100%|██████████████████████████████████████████████████████████████████████| 1014544/1014544 [02:16<00:00, 7450.73it/s]

# %%
 
from IPython.display import Image
from IPython.display import display

df = pd.merge(first_100_annos,images)
import matplotlib.pyplot as plt
for name,row in df[df['labelId']=='34'].iterrows():
  display(Image(url=row['url'],height=200,width=200))
# Out:
# 100%|██████████████████████████████████████████████████████████████████████| 1014544/1014544 [02:34<00:00, 6564.90it/s]

# %%
with open('../01_input_data/titles.json','r') as f:
  titles = json.load(f)
with open('../01_input_data/keywords.json','r') as f:
  keywords = json.load(f)

# %%
from IPython.display import Image
from IPython.display import display

df = pd.merge(first_100_annos,images)
import matplotlib.pyplot as plt
for name,row in df[df['labelId']=='153'].iterrows():
  display(Image(url=row['url'],height=200,width=200))
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None

# %%
stack = []
for imageId in first_100_annos[first_100_annos['labelId'] == '153']['imageId'].values:
  if imageId in titles.keys():
    stack += titles[imageId]
pd.Series(stack).value_counts()
# Out:
# women          38
# fashion        32
# dress          29
# sleeve         27
# new            23
# long           23
# sweater        17
# women's        16
#                14
# t-shirt        13
# summer         12
# tops           11
# men's          11
# lace           11
# short          11
# autumn         10
# chiffon        10
# sexy           10
# shirt          10
# cotton         10
# casual         10
# print          10
# slim           10
# blouse          9
# round           9
# hoodies         9
# winter          7
# 2014            7
# sleeveless      7
# sweatshirt      6
#                ..
# (4              1
# stereo          1
# dhstyles        1
# &               1
# detalle         1
# 54              1
# #3              1
# sun             1
# jersey          1
# super           1
# abrigo          1
# back            1
# swimsuit        1
# (long           1
# ol              1
# gradient        1
# crop            1
# red             1
# hksg            1
# ...

# %%
annotations.applymap(int).groupby('labelId').count().to_csv('annotation_count.csv',sep=';')

# %%
keywords
# Out:
# {'486': ['cosplay',
#   'cosplaycostume',
#   'costume',
#   'socks',
#   'outfits',
#   'kneehigh',
#   "women'sfashion",
#   'outfitsock',
#   'amnesia',
#   'protagonist',
#   'heroine',
#   'stockings',
#   'anime'],
#  '18777': ['mini',
#   'fashion',
#   'jewelry',
#   'summer',
#   'geometry',
#   'spring',
#   'dress',
#   "women'sfashion",
#   'roundneck',
#   'multicolor',
#   'diamond',
#   'skater',
#   'cotton',
#   'casual',
#   'women'],
#  '56849': ['roundneck',
#   'korea',
#   'giftsformen',
#   'sleeve',
#   'pulloversweater',
#   'koreanstyle',
#   'necks',
#   'slimsweater',
#   'contrastcolorsweater',
#   'pullovers',
#   'knitted',
#   'longsleeve',
#   "men'sfashion",
#   'fashion',
#   'knittedsweater',
#   'korean',
#   'navybluesweater',
#   'sweaters',
#   'menssweater'],
#  '73278': ['blues',
#   'jacketmickey',
#   'fashion',
#   'cotton',
#   'winter',
#   'coat',
#   'men',
#   'jacket',
#   'clothinghunter',
#   'chinajacketmickeysupplier',
# ...
